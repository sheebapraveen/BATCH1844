# %% [markdown]
# # Avacado case study

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\Praveen kumar\Downloads\avocado.csv\avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1               1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2               2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3               3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4               4  11/29/2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7    2/4/2018          1.63      17074.83  2046.96    1529.20
# 18245           8   1/28/2018          1.71      13888.04  1191.70    3431.50
# 18246           9   1/21/2018          1.87      13766.76  1191.92    2452.79
# 18247          10   1/14/2018          1.93      16205.22  1527.63    2981.04
# 18248          11    1/7/2018          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# Here we have 18249  rows and 14 columns

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1               1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2               2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3               3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4               4  11/29/2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7    2/4/2018          1.63      17074.83  2046.96    1529.20
# 18245           8   1/28/2018          1.71      13888.04  1191.70    3431.50
# 18246           9   1/21/2018          1.87      13766.76  1191.92    2452.79
# 18247          10   1/14/2018          1.93      16205.22  1527.63    2981.04
# 18248          11    1/7/2018          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.AveragePrice.value_counts()
# Out:
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.25      1
# 3.12      1
# 2.68      1
# 3.03      1
# 3.17      1
# Name: AveragePrice, Length: 259, dtype: int64

# %%
df.AveragePrice.unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.03, 1.18, 1.29, 1.25, 0.71,
#        0.94, 0.91, 1.39, 1.4 , 1.36, 1.3 , 1.54, 1.59, 1.56, 1.38, 1.49,
#        1.5 , 1.47, 1.42, 1.41, 1.44, 1.52, 0.9 , 0.87, 0.78, 0.92, 0.83,
#        0.88, 0.84, 0.85, 1.21, 0.79, 0.89, 0.86, 0.8 , 0.82, 0.74, 0.81,
#        0.77, 0.75, 0.65, 0.73, 0.68, 0.72, 0.67, 0.76, 0.62, 0.7 , 0.66,
#        1.46, 0.49, 0.53, 0.56, 0.6 , 0.58, 0.54, 0.52, 0.51, 0.57, 0.63,
#        0.64, 0.61, 1.48, 1.55, 1.58, 1.53, 1.57, 1.51, 0.69, 1.62, 1.63,
#        1.61, 1.6 , 1.73, 1.8 , 1.86, 1.85, 1.69, 1.66, 1.65, 1.64, 1.67,
#        1.68, 1.82, 2.07, 1.84, 1.83, 1.7 , 1.72, 1.81, 1.78, 0.59, 1.9 ,
#        1.93, 1.99, 1.95, 1.89, 1.76, 1.71, 1.74, 0.55, 1.79, 1.75, 1.94,
# ...

# %% [markdown]
# # To check missing values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# plotting the heatmap for null function

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# No null values present in the dataset

# %% [markdown]
# # Statistical summary

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# Univariate Analysis

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df['Unnamed: 0'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['AveragePrice'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Total Volume'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['4046'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['4225'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['4770'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Total Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Small Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Large Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['year'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['XLarge Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bivariate Analysis

# %%
sns.scatterplot(data=df,x='Unnamed: 0',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='AveragePrice'>

# %% [markdown]
# from the solution,concluded that it is not a linear solution,the price is increasing and decreasing with unnamed:0

# %%
sns.scatterplot(data=df,x='Date',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='AveragePrice'>

# %% [markdown]
#  Here the date and prices are both similarly increasing and decreasing.

# %%
sns.scatterplot(data=df,x='Total Volume',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='AveragePrice'>

# %% [markdown]
# from this plot,concluded that the price increases for a particular range then decreases with increase in volume and the extreme outliers are present.

# %%
sns.scatterplot(data=df,x='4046',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='4046', ylabel='AveragePrice'>

# %% [markdown]
# In this plot,as same before price increases for a range after the price decreases with increases in volume with extreme outliers

# %%
sns.scatterplot(data=df,x='4225',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='4225', ylabel='AveragePrice'>

# %% [markdown]
# This plot is also same as before plots.

# %%
sns.scatterplot(data=df,x='4770',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='4770', ylabel='AveragePrice'>

# %% [markdown]
# here the average price decreases with increases in 4770.and also extreme outliers are seen

# %%
sns.scatterplot(data=df,x='Total Bags',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='AveragePrice'>

# %% [markdown]
# From here too,the average price increases linearly and then decreases with increases in volume with extreme outliers are present

# %%
sns.scatterplot(data=df,x='Small Bags',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='AveragePrice'>

# %% [markdown]
# whether the large bags,XLarge bags vs average price  had the same relation in the resting plots and there are outliers are present.

# %%
sns.scatterplot(data=df,x='type',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %% [markdown]
# Here we can see two types and prices for conventional and organic prices is increases more.

# %%
sns.scatterplot(data=df,x='year',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %% [markdown]
# The average prices are increases for different years and decreases at 2018

# %%
sns.scatterplot(data=df,x='region',y='AveragePrice')
# Out:
# <AxesSubplot:xlabel='region', ylabel='AveragePrice'>

# %% [markdown]
# The above plot indicates the price in each region of the country.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df)

# %% [markdown]
# These are the relation of each column with other columns in the dataset

# %%
dfcorr=df.corr()

# %%
dfcorr
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
sns.heatmap(dfcorr)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,15))
sns.heatmap(dfcorr,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # checking Skewness

# %%
sns.distplot(df['Unnamed: 0'])
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='Density'>

# %%
sns.distplot(df['Total Volume'])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %%
sns.distplot(df['4046'])
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Density'>

# %%
sns.distplot(df['4225'])
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Density'>

# %%
sns.distplot(df['4770'])
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Density'>

# %%
sns.distplot(df['Total Bags'])
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %%
sns.distplot(df['Large Bags'])
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Density'>

# %%
sns.distplot(df['Small Bags'])
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Density'>

# %%
sns.distplot(df['XLarge Bags'])
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Density'>

# %%
sns.distplot(df['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %% [markdown]
# # Data Cleaning

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
df['Date']=le.fit_transform(df['Date'])

# %%
df['type']=le.fit_transform(df['type'])

# %%
df['region']=le.fit_transform(df['region'])

# %%
df['Date']
# Out:
# 0        53
# 1        50
# 2        47
# 3        57
# 4        41
#          ..
# 18244    70
# 18245    11
# 18246     7
# 18247     3
# 18248    16
# Name: Date, Length: 18249, dtype: int32

# %%
df['type']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 18244    1
# 18245    1
# 18246    1
# 18247    1
# 18248    1
# Name: type, Length: 18249, dtype: int32

# %%
df['region']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 18244    53
# 18245    53
# 18246    53
# 18247    53
# 18248    53
# Name: region, Length: 18249, dtype: int32

# %%
df
# Out:
#        Unnamed: 0  Date  AveragePrice  Total Volume     4046       4225  \
# 0               0    53          1.33      64236.62  1036.74   54454.85
# 1               1    50          1.35      54876.98   674.28   44638.81
# 2               2    47          0.93     118220.22   794.70  109149.67
# 3               3    57          1.08      78992.15  1132.00   71976.41
# 4               4    41          1.28      51039.60   941.48   43838.39
# ...           ...   ...           ...           ...      ...        ...
# 18244           7    70          1.63      17074.83  2046.96    1529.20
# 18245           8    11          1.71      13888.04  1191.70    3431.50
# 18246           9     7          1.87      13766.76  1191.92    2452.79
# 18247          10     3          1.93      16205.22  1527.63    2981.04
# 18248          11    16          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  \
# ...

# %% [markdown]
# The complete dataset is present in integer format.we are losing high data while removing the outlier process.so not taking the outlier process

# %% [markdown]
# # Removing skewness

# %%
x1=df.drop('AveragePrice',axis=1)
y1=df['AveragePrice']

# %% [markdown]
# Here we are separating the independant variable and the target variable

# %%
x1.skew()
# Out:
# Unnamed: 0       0.108334
# Date             0.000124
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# dtype: float64

# %%
plt.figure(figsize=(25,20))
for i in enumerate(x1.columns):
    plt.subplot(5,3,i[0]+1)
    sns.distplot(df[i[1]],color='r')

# %% [markdown]
# Here we are removing the skewness from the columns.

# %% [markdown]
# # Now importing the power_transform

# %%
from sklearn.preprocessing import power_transform

# %%
df_1=power_transform(x1)
df_1=pd.DataFrame(df_1,columns=x1.columns)

# %%
df_1.skew()
# Out:
# Unnamed: 0     -0.242585
# Date           -0.277804
# Total Volume    0.011171
# 4046           -0.022679
# 4225           -0.017740
# 4770            0.032184
# Total Bags     -0.001626
# Small Bags      0.007058
# Large Bags     -0.073809
# XLarge Bags     0.793520
# type            0.000329
# year            0.213156
# region         -0.261443
# dtype: float64

# %% [markdown]
# skewness has been removed

# %%
df_1.head()
# Out:
#    Unnamed: 0      Date  Total Volume      4046      4225      4770  \
# 0   -1.968845 -0.538857     -0.086605 -0.658619  0.307313 -0.247250
# 1   -1.792619 -0.605308     -0.155746 -0.776870  0.231647 -0.201041
# 2   -1.648366 -0.672885      0.179327 -0.731947  0.579503 -0.007072
# 3   -1.521609 -0.451872      0.003876 -0.634200  0.415100 -0.148322
# 4   -1.406451 -0.811799     -0.187640 -0.685293  0.224806 -0.137918
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags      type      year  \
# 0   -0.524004   -0.340627   -0.773351    -0.699849 -0.999836 -1.221895
# 1   -0.485890   -0.306425   -0.763435    -0.699849 -0.999836 -1.221895
# 2   -0.552018   -0.366303   -0.750820    -0.699849 -0.999836 -1.221895
# 3   -0.695449   -0.496853   -0.691865    -0.699849 -0.999836 -1.221895
# 4   -0.669157   -0.477201   -0.600975    -0.699849 -0.999836 -1.221895
#
#      region
# 0 -2.011552
# 1 -2.011552
# 2 -2.011552
# 3 -2.011552
# 4 -2.011552

# %% [markdown]
# # Model Building

# %% [markdown]
# LINEAR REGRESSiON PROCESS

# %% [markdown]
# importing the necessary libraries

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# creating train test split

# %%
x=df_1

# %%
x.shape
# Out:
# (18249, 13)

# %%
y1.shape
# Out:
# (18249, 1)

# %%
y1=y1.reshape(-1,1)

# %%
x_train,x_test,y1_train,y1_test=train_test_split(x,y,test_size=0.30,random_state=50)

# %%
x_train.shape
# Out:
# (12774, 13)

# %%
x_test.shape
# Out:
# (5475, 13)

# %%
y_train.shape
# Out:
# (12774, 1)

# %%
y_test.shape
# Out:
# (5475, 1)

# %% [markdown]
# # Random state

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
LR=LinearRegression()
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)

# %%
print(f'At random state{i}, The training accuracy is :-{r2_score(y_train,LR_predict_train)}')
print(f'At random state{i}, The test accuracy is :-{r2_score(y_test,LR_predict_test)}')
print('\n')
# Out:
# At random state99, The training accuracy is :-0.5495275196450273
# At random state99, The test accuracy is :-0.539787094483598

# %% [markdown]
# Random state 99 giving the best accuracy.

# %% [markdown]
# # LINEAR REGRESSION

# %%
LR.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)
# Out:
# 0.5495275196450273

# %%
print('MSE:',mean_squared_error(LR_predict,y_test))
print('MAE:',mean_absolute_error(LR_predict,y_test))
print('r2_score:',r2_score(LR_predict,y_test))
# Out:
# MSE: 0.07382011238582542
# MAE: 0.21097500234777913
# r2_score: 0.16465265135896245

# %% [markdown]
# # Ridge

# %%
from sklearn.linear_model import Ridge

R=Ridge()
R.fit(x_train,y_train)
print(R.score(x_train,y_train))
R_predict=R.predict(x_test)
# Out:
# 0.5495272986460182

# %%
print('MSE:',mean_squared_error(R_predict,y_test))
print('MAE:',mean_absolute_error(R_predict,y_test))
print('r2_score:',r2_score(R_predict,y_test))
# Out:
# MSE: 0.07382062353204996
# MAE: 0.21097608210037933
# r2_score: 0.16423830217042334

# %% [markdown]
# # SVR

# %% [markdown]
# SVR LINEAR

# %%
from sklearn.svm import SVR

# %%
svr=SVR(kernel='linear')
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
svr_predict=svr.predict(x_test)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5393985200263613

# %% [markdown]
# SVR(POLY)

# %%
svr_p=SVR(kernel='poly')
svr_p.fit(x_train,y_train)
print(svr_p.score(x_train,y_train))
svrpred_p=svr_p.predict(x_test)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.7156652902530539

# %%
print('MSE:',mean_squared_error(svrpred_p,y_test))
print('MAE:',mean_absolute_error(svrpred_p,y_test))
print('r2_score:',r2_score(svrpred_p,y_test))
# Out:
# MSE: 0.04845368809616653
# MAE: 0.16449398086442746
# r2_score: 0.5417554106193144

# %% [markdown]
# # Random Forest Regressor

# %%
#importing necessary libraries
from sklearn.ensemble import RandomForestRegressor

# %%
RF=RandomForestRegressor()
RF.fit(x_train,y_train)
print(RF.score(x_train,y_train))
RF_PRED=RF.predict(x_test)
# Out:
# C:\Users\PRAVEE~1\AppData\Local\Temp/ipykernel_6312/3696011945.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF.fit(x_train,y_train)
# 0.9839590877936563

# %%
print('MSE:',mean_squared_error(RF_PRED,y_test))
print('MAE:',mean_absolute_error(RF_PRED,y_test))
print('r2_score:',r2_score(RF_PRED,y_test))
# Out:
# MSE: 0.017261671926940635
# MAE: 0.0916939908675799
# r2_score: 0.8682464838495869

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
print(DTR.score(x_train,y_train))
DTR_PRED=DTR.predict(x_test)
# Out:
# 1.0

# %%
print('MSE:',mean_squared_error(DTR_PRED,y_test))
print('MAE:',mean_absolute_error(DTR_PRED,y_test))
print('r2_score:',r2_score(DTR_PRED,y_test))
# Out:
# MSE: 0.03933092237442922
# MAE: 0.12751780821917807
# r2_score: 0.764926454130584

# %% [markdown]
# # Gradient boosting regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
print(GBR.score(x_train,y_train))
GBR_PRED=GBR.predict(x_test)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\ensemble\_gb.py:570: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.767129904974346

# %%
print('MSE:',mean_squared_error(GBR_PRED,y_test))
print('MAE:',mean_absolute_error(GBR_PRED,y_test))
print('r2_score:',r2_score(GBR_PRED,y_test))
# Out:
# MSE: 0.03856821736104183
# MAE: 0.14828865488719872
# r2_score: 0.6242719307161612

# %% [markdown]
# Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
np.random.seed(10)
def rmse_cv(model,x,y):
    rmse=-(cross_val_score(model,x,y,scoring='neg_mean_squared_error',cv=10))
    return(rmse)

# %%
models=[LinearRegression(),
       Ridge(),
       SVR(kernel='linear'),
       SVR(kernel='poly'),
        RandomForestRegressor(),
        DecisionTreeRegressor(),
        GradientBoostingRegressor()]
names=['LR','R','svr','svr_p','RF','DTR','GBR']

for model,name in zip(models,names):
    score=rmse_cv(model,x,y)
    print("{} : {:.6f}, {:4f}".format(name,score.mean(),score.std()))
# Out:
# LR : 0.080476, 0.033185
# R : 0.080471, 0.033183
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# # saving the model

# %%
import joblib

# %%
joblib.dump(DTR_PRED,'Avacado prediction')
# Out:
# ['Avacado prediction']
